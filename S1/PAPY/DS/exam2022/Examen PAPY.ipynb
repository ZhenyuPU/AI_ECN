# %% [markdown]
# # **Exament Programmation AAvancée en Python (PAPY)**

# %% [markdown]
# #Correction#
# ## **Partie 1: Connaissances Générales [9pts]**
# ## **Connaissance de python[3,5pts]**
# **Question 1.1**[2pts]
#
# Un mutuable est un type dont le contenue peut être modifié après sa création.
# A l'inverse un immuable ne peut être modifié après sa création. Ainsi
# **Question 1.2**[1pts]
#
# Example : Muable (list,dict)/Immuable(str,tuple)
#
# **Question 2.1**[1pts]
#
# * v = (v[0],nouvellleVal, v[2])
# * v[1] = new_valeur
#
# **Question 2.2**[1pts]
#
# * v = (*v, new_val)
# * v.append(new_val)
#
# **Question 3**[2pts]
#
# Le dictionnaire est mutuable et fonctionne avec des paires cle-valeur
# >> D = {"A" : 1 , "A1" : 3}
# >> Print (D["A1"])
#
# **Question 4**[1pts]
#
# Le docstring est la documentation interne du code python. On la retrouve pour les modules, classes et fonctions. Il peut s'écrire entre "" et """ texte""" pour la multiligne. Il se situe juste après la déclaration.
#
# **Question 5**[1pts]
#
# Renvoie 3
# Explication a voir...
#
# **Question 6.1**[1pts]
#
# L n'as pas changé.
# On ne touche pas à l'affection de L.
#
# **Question 6.2**[1pts]
#
# L = [1, "a", 2], puisque les deux variable L et L2 pointent vers le même mutuable
#
# **Question 7**[1pts]
#
# Un module est un fichier python qui contient du code. On peut l'importer depuis un autre répertoire.
#
# **Question 8**[1pts]
#
# * Ex1: import numpy as np // np.linespace(0,1,3)
# * Ex2: from numpy import linespace // linespace(0,1,3)
#
# ## **Etre un bon developpeur[2,5pts]**
# **Question 1**[1pts]
#
# L'environement python permet de s'assurer que l'on utilise les bonnes versions python et des modules ainsi que leur compatibilité. C'est aussi de cette manière que l'on s'assure de ne pas polluer le python système
#
# **Question 2**[1pts]
#
# On peut installer numpy avec pip ou conda.
# Exemple: pip install numpy
#
# **Question 3**[2pts]
#
# Un décorateur est une fonction qui modifie le comportement d'autres fonctions.
# @décorateur
# def function():
# On peut modifier le comportement de fonction. Par exemple pour écrire un timer qui pourra équiper plusieurs fonction.
#
# **Question 4**[3pts]
#
# Tester son code permet de s'assurer que celui-ci fonctionne comme attendu. En particulier cela permet de mettre en place des tests de non-régréssion qui assurent la fiabilité des fonctionnalités déja installé, facilite aussi le debug. On peut utiliser doctest dans les docstring pour tester automatiquement le code en offrant des exemples aux utilisateur du code
#
#
# **Question 5**[1pts]
#
# GRAVITY = 9.81 (suivant les recommandations python PEP)
#
#
# ## **Commentaire de code[3pts]**
# **Question 1**[2pts]
# [0,5, 1, 0,5pts]
#    * La première valeur d'entry vaux -1
#    * Ce qui va lever une erreur arithmétique puisque log n'est définie qu'au dessus de 0
#    * Il faudrais ajouter un test pour vérifié que la valeur n'est pas < 0
#
#
# **Question 2**[1pts]
#
# Il faut ajouter une documentation docstring et des test/try/except
#
# **Question 3**[3pts]
#
# En python puisque le code n'est pa compilé, l'exécution des boucles est lentes. On va donc chercher à en réduire le nombre:
# * réduire la compléxité algo
# * utiliser des bibliothèques
# * compréhension des binding / compilation
# * parrallélisme ou multithreading.
#
# **Question 4**[4pts]
#
# Réécriture du code.

# %% [markdown]
# Total sur 9points
# Connaissance [3,5pts] [13pts]
# Etre un bon developpeur [2,5pts] [8pts]
# Commentaire de code [3pts] [10pts]
